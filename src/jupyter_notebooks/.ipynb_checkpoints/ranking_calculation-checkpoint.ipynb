# %%
import pandas as pd
import numpy as np
import re
import pickle
import math

# %%
def retr_model_info():
    with open('../model_and_cols.pkl', 'rb') as f:
        county_info_df = pickle.load(f)
        model = pickle.load(f)
        cols = pickle.load(f)
    return(county_info_df, model, cols)

# def index_finder(county, state, df):
#     if len(state) == 2:
#         the_state = state.upper()
#         state_df = df[df['state_code'] == the_state]
#     else:
#         the_state = state.lower().title()
#         state_df = df[df['state_name'] == the_state]
#     county_list = list(state_df['county_name'])
#     for elem in county_list:
#         m = re.search(county, elem, re.IGNORECASE)
#         if m:
#             req_county = elem
#             break
#     m = re.search('aleutians', req_county, re.IGNORECASE)
#     if m and county != req_county:
#         aleu = input('Are you interested in 1)Aleutians East Borough or 2)Aleutians West Census Area?\nEnter 1 or 2: ')
#         if aleu == '1': req_county = 'Aleutians East Borough'
#         elif aleu == '2': req_county = 'Aleutians West Census Area'

#     index = state_df.index[state_df['county_name'] == req_county].tolist()[0]
#     return(index, req_county)


# the calculation of err_down and err_up are modified code obtained from http://blog.datadive.net/prediction-intervals-for-random-forests/
def predict_bars(idx, county_info_df, model, cols, percentile=95):
    X = np.asarray(county_info_df.iloc[idx][cols]).reshape(1,-1)
    y = county_info_df.iloc[idx]['bars']
    y_pred = model.predict(X)
#     preds = []
#     for pred in model.estimators_:
#         preds.append(pred.predict(X)[0])
#     err_down = (np.percentile(preds, (100 - percentile) / 2. ))
#     err_up = (np.percentile(preds, 100 - (100 - percentile) / 2.))
    return(max(0,int(y_pred)), int(y))

# %%
county_info_df, model, cols = retr_model_info()

#     state = input('Enter the state you are interested in:\n')
#     county = input('\nEnter the county you are interested in:\n')
#     index, req_county = index_finder(county, state, county_info_df)
r=[]
for idx in range(len(county_info_df)):  
    pred_y, actual_y = predict_bars(idx, county_info_df, model, cols)
    r.append(round(pred_y/actual_y,2))

# %%
r_series = pd.Series(r)
county_info_df['model/actual'] = r_series
county_info_df.head()
# Out:
#    geo_id state_name state_code         county_name  area_sqmi  pop_est_2015  \
# 0    1001    Alabama         AL  Autauga County, AL    594.439         55347
# 1    1003    Alabama         AL  Baldwin County, AL   1589.808        203709
# 2    1005    Alabama         AL  Barbour County, AL    884.877         26489
# 3    1007    Alabama         AL     Bibb County, AL    622.583         22583
# 4    1009    Alabama         AL   Blount County, AL    644.807         57673
#
#    hotels  bars  model/actual
# 0     9.0   4.0          2.00
# 1    85.0  36.0          1.17
# 2    12.0   4.0          2.00
# 3     4.0   4.0          2.00
# 4     5.0   4.0          2.00

# %%
county_info_df.sort_values('model/actual', ascending=False).head(10)
# Out:
#       geo_id state_name state_code                county_name  area_sqmi  \
# 2919   51550   Virginia         VA        Chesapeake city, VA    340.800
# 2840   51041   Virginia         VA    Chesterfield County, VA    423.373
# 173     5125   Arkansas         AR          Saline County, AR    723.619
# 2821   51003   Virginia         VA       Albemarle County, VA    720.802
# 2801   49049       Utah         UT            Utah County, UT   2003.573
# 2862   51087   Virginia         VA         Henrico County, VA    233.703
# 2904   51177   Virginia         VA    Spotsylvania County, VA    401.494
# 2892   51153   Virginia         VA  Prince William County, VA    336.413
# 444    13117    Georgia         GA         Forsyth County, GA    224.054
# 455    13139    Georgia         GA            Hall County, GA    392.784
#
#       pop_est_2015  hotels  bars  model/actual
# 2919        235429    60.0   2.0         21.00
# 2840        335687    85.0   5.0         11.00
# 173         117460    27.0   2.0         10.00
# 2821        105703    44.0   2.0          9.00
# 2801        575205    72.0  13.0          8.31
# 2862        325155    95.0   9.0          6.67
# 2904        130475    27.0   3.0          6.67
# 2892        451721    68.0  15.0          6.40
# 444         212438    25.0   7.0          6.00
# 455         193535    28.0   7.0          5.86

# %%
county_info_df['pop_est_2015'].median()
# Out:
# 25698.5

# %%
best_to_open_df = county_info_df[['model/actual', 'county_name', 'area_sqmi', 'pop_est_2015']].sort_values('model/actual')
best_to_open_df.index = np.arange(1, len(best_to_open_df) + 1)
best_to_open_df.columns = ['model/actual', 'County and State', 'County Area', 'Population']
best_to_open_df.head(20)
# Out:
#     model/actual        County and State  County Area  Population
# 1           0.10     Chippewa County, WI     1008.353       63531
# 2           0.11    Marinette County, WI     1399.356       40884
# 3           0.11      Douglas County, WI     1304.139       43601
# 4           0.12      Portage County, WI      800.821       70408
# 5           0.12      Shawano County, WI      893.019       41304
# 6           0.12   Silver Bow County, MT      717.995       34622
# 7           0.12      Waupaca County, WI      747.620       51945
# 8           0.12       Oconto County, WI      997.988       37435
# 9           0.13    Manitowoc County, WI      589.312       79806
# 10          0.13        Grant County, WI     1146.866       52250
# 11          0.13       Oneida County, WI     1113.479       35567
# 12          0.13      Lincoln County, WI      878.860       27980
# 13          0.14        Clark County, WI     1209.708       34445
# 14          0.14        Dodge County, WI      875.674       88502
# 15          0.14         Wood County, WI      792.947       73435
# 16          0.15         Sauk County, WI      830.895       63642
# 17          0.15    Jefferson County, WI      556.464       84559
# 18          0.16  Trempealeau County, WI      733.004       29550
# 19          0.16     Marathon County, WI     1545.003      135868
# 20          0.17       Pierce County, WI      573.749       40889

# %%
worse_to_open_df = county_info_df[['model/actual', 'county_name', 'area_sqmi', 'pop_est_2015']].sort_values('model/actual', ascending=False)
worse_to_open_df.index = np.arange(1, len(best_to_open_df) + 1)
worse_to_open_df.columns = ['model/actual', 'County and State', 'County Area', 'Population']
worse_to_open_df.head(20)
# Out:
#     model/actual           County and State  County Area  Population
# 1          21.00        Chesapeake city, VA      340.800      235429
# 2          11.00    Chesterfield County, VA      423.373      335687
# 3          10.00          Saline County, AR      723.619      117460
# 4           9.00       Albemarle County, VA      720.802      105703
# 5           8.31            Utah County, UT     2003.573      575205
# 6           6.67         Henrico County, VA      233.703      325155
# 7           6.67    Spotsylvania County, VA      401.494      130475
# 8           6.40  Prince William County, VA      336.413      451721
# 9           6.00         Forsyth County, GA      224.054      212438
# 10          5.86            Hall County, GA      392.784      193535
# 11          5.33          Howard County, MD      250.944      313414
# 12          5.25           Union County, NC      631.641      222742
# 13          5.00       Merrimack County, NH      934.134      147994
# 14          5.00        San Juan County, NM     5513.183      118737
# 15          5.00        Randolph County, NC      781.696      142799
# 16          5.00        Stafford County, VA      269.050      142003
# 17          5.00        Paulding County, GA      312.292      152238
# 18          5.00       Strafford County, NH      368.883      126825
# 19          5.00           Cache County, UT     1164.723      120783
# 20          5.00          Lonoke County, AR      770.931       71645
