# %%
import numpy as np
import pandas as pd
from csv_utf8ed_processing import processing
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_pop = pd.read_csv('../data/2015_pop_and_area.csv')
df_pop2 = df_pop[['geo_id', 'state_name', 'state_code', 'county_name', 'area_sqmi', 'log_aland_sqmi', 'pop_est_2015', 'log_pop_est_2015', 'pop_den_2015', 'log_pop_den_2015']]
df_pop2.head()
# Out:
#    geo_id state_name state_code     county_name  area_sqmi  log_aland_sqmi  \
# 0    1001    Alabama         AL  Autauga County    594.439        6.387618
# 1    1003    Alabama         AL  Baldwin County   1589.808        7.371369
# 2    1005    Alabama         AL  Barbour County    884.877        6.785449
# 3    1007    Alabama         AL     Bibb County    622.583        6.433877
# 4    1009    Alabama         AL   Blount County    644.807        6.468951
#
#    pop_est_2015  log_pop_est_2015  pop_den_2015  log_pop_den_2015
# 0         55347         10.921378     93.107956          4.533760
# 1        203709         12.224448    128.134341          4.853079
# 2         26489         10.184485     29.935234          3.399036
# 3         22583         10.024953     36.273075          3.591076
# 4         57673         10.962544     89.442267          4.493593

# %%
type(df_pop2['geo_id'][0])
# Out:
# numpy.int64

# %%
df_pop2['geo_id'] = df_pop2['geo_id'].astype(str)
type(df_pop2['geo_id'][0])
# Out:
# /anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# str

# %%
dfb1 = processing('../data/BP_2015_00A1_with_ann_bar_utf8.csv', 'ESTAB', 'bar_big')
dfb1.head()
# Out:
#   geo_id  bar_big
# 1   1003       12
# 2   1015        4
# 3   1031        2
# 4   1033        3
# 5   1045        3

# %%
type(dfb1['bar_big'][1])
# Out:
# numpy.int64

# %%
result = pd.merge(df_pop2, dfb1, on='geo_id', how='outer')
result.head()
# Out:
#   geo_id state_name state_code     county_name  area_sqmi  log_aland_sqmi  \
# 0   1001    Alabama         AL  Autauga County    594.439        6.387618
# 1   1003    Alabama         AL  Baldwin County   1589.808        7.371369
# 2   1005    Alabama         AL  Barbour County    884.877        6.785449
# 3   1007    Alabama         AL     Bibb County    622.583        6.433877
# 4   1009    Alabama         AL   Blount County    644.807        6.468951
#
#    pop_est_2015  log_pop_est_2015  pop_den_2015  log_pop_den_2015  bar_big
# 0         55347         10.921378     93.107956          4.533760      NaN
# 1        203709         12.224448    128.134341          4.853079     12.0
# 2         26489         10.184485     29.935234          3.399036      NaN
# 3         22583         10.024953     36.273075          3.591076      NaN
# 4         57673         10.962544     89.442267          4.493593      NaN

# %%
dfb2 = processing('../data/NES_2015_00A2_with_ann_bar_utf8.csv', 'NESTAB', 'bar_small', all_numeric=False)
dfb2.head()
# Out:
#   geo_id bar_small
# 1   1001         D
# 2   1003        24
# 3   1005         D
# 4   1007         D
# 5   1009         D

# %%
result2 = pd.merge(result, dfb2, on='geo_id', how='left')
result2.head()
# Out:
#   geo_id state_name state_code     county_name  area_sqmi  log_aland_sqmi  \
# 0   1001    Alabama         AL  Autauga County    594.439        6.387618
# 1   1003    Alabama         AL  Baldwin County   1589.808        7.371369
# 2   1005    Alabama         AL  Barbour County    884.877        6.785449
# 3   1007    Alabama         AL     Bibb County    622.583        6.433877
# 4   1009    Alabama         AL   Blount County    644.807        6.468951
#
#    pop_est_2015  log_pop_est_2015  pop_den_2015  log_pop_den_2015  bar_big  \
# 0         55347         10.921378     93.107956          4.533760      NaN
# 1        203709         12.224448    128.134341          4.853079     12.0
# 2         26489         10.184485     29.935234          3.399036      NaN
# 3         22583         10.024953     36.273075          3.591076      NaN
# 4         57673         10.962544     89.442267          4.493593      NaN
#
#   bar_small
# 0         D
# 1        24
# 2         D
# 3         D
# 4         D

# %%
print((result2['bar_small'] == 'D').sum(), (result2['bar_small'] == 'S').sum())
# Out:
# 1034 14

# %%
# resultD = (result2['bar_small'] == 'D')
resultD = result2.iloc[np.where(result2["bar_small"] == 'D')]
resultS = result2.iloc[np.where(result2["bar_small"] == 'S')]
resultNDS = result2.iloc[np.where(result2["bar_small"] != 'D') and np.where(result2["bar_small"] != 'S')]

# %%
resultD['pop_est_2015'].hist()
plt.show()

# %%
resultS['pop_est_2015'].hist()
plt.show()

# %%
resultNDS['log_pop_est_2015'].hist()
plt.show()

# %%
dfh1 = processing('../data/BP_2015_00A1_with_ann_hot_utf8.csv', 'ESTAB', 'hot_big')
dfh1.head()
# Out:
#   geo_id  hot_big
# 1   1001        8
# 2   1003       51
# 3   1005        9
# 4   1009        2
# 5   1013        7

# %%
dfh2 = processing('../data/NES_2015_00A2_with_ann_hot_utf8.csv', 'NESTAB', 'hot_small', all_numeric=False)
dfh2.head()
# Out:
#   geo_id hot_small
# 1   1001         D
# 2   1003        34
# 3   1005         3
# 4   1007         D
# 5   1009         3

# %%
print((dfh2['hot_small'] == 'D').sum(), (dfh2['hot_small'] == 'S').sum())
# Out:
# 977 3

# %%
(dfh2['hot_small']=='1').sum()
# Out:
# 0

# %%
result3 = pd.merge(result2, dfh1, on='geo_id', how='left')
result4 = pd.merge(result3, dfh2, on='geo_id', how='left')
result4.head()
# Out:
#   geo_id state_name state_code     county_name  area_sqmi  log_aland_sqmi  \
# 0   1001    Alabama         AL  Autauga County    594.439        6.387618
# 1   1003    Alabama         AL  Baldwin County   1589.808        7.371369
# 2   1005    Alabama         AL  Barbour County    884.877        6.785449
# 3   1007    Alabama         AL     Bibb County    622.583        6.433877
# 4   1009    Alabama         AL   Blount County    644.807        6.468951
#
#    pop_est_2015  log_pop_est_2015  pop_den_2015  log_pop_den_2015  bar_big  \
# 0         55347         10.921378     93.107956          4.533760      NaN
# 1        203709         12.224448    128.134341          4.853079     12.0
# 2         26489         10.184485     29.935234          3.399036      NaN
# 3         22583         10.024953     36.273075          3.591076      NaN
# 4         57673         10.962544     89.442267          4.493593      NaN
#
#   bar_small  hot_big hot_small
# 0         D      8.0         D
# 1        24     51.0        34
# 2         D      9.0         3
# 3         D      NaN         D
# 4         D      2.0         3

# %%
result_any_S = result4.loc[(result4['bar_small'] == 'S') | (result4['hot_small'] == 'S')]
result_any_S
# Out:
#      geo_id     state_name state_code          county_name  area_sqmi  \
# 85     2185         Alaska         AK  North Slope Borough  88839.308
# 205    6039     California         CA        Madera County   2137.098
# 421   13071        Georgia         GA      Colquitt County    546.986
# 443   13115        Georgia         GA         Floyd County    509.923
# 524   13279        Georgia         GA        Toombs County    364.006
# 580   16059          Idaho         ID         Lemhi County   4563.293
# 1155  22085      Louisiana         LA        Sabine Parish    866.656
# 1248  26035       Michigan         MI         Clare County    564.335
# 1407  28013    Mississippi         MS       Calhoun County    586.573
# 1416  28031    Mississippi         MS     Covington County    413.796
# 1732  31157       Nebraska         NE  Scotts Bluff County    739.401
# 1853  36051       New York         NY    Livingston County    631.762
# 2140  40019       Oklahoma         OK        Carter County    822.177
# 2205  40149       Oklahoma         OK       Washita County   1003.167
# 2406  46091   South Dakota         SD      Marshall County    838.085
# 2679  48313          Texas         TX       Madison County    466.065
# 3025  54067  West Virginia         WV      Nicholas County    646.835
#
#       log_aland_sqmi  pop_est_2015  log_pop_est_2015  pop_den_2015  \
# 85         11.394584          9687          9.178540      0.109040
# 205         7.667204        154998         11.951167     72.527324
# 421         6.304423         45844         10.733000     83.812017
# 443         6.234260         96504         11.477340    189.252103
# 524         5.897170         27241         10.212478     74.836679
# 580         8.425800          7735          8.953511      1.695048
# 1155        6.764642         24186         10.093529     27.907267
# 1248        6.335648         30553         10.327218     54.139828
# 1407        6.374297         14717          9.596759     25.089801
# 1416        6.025373         19543          9.880372     47.228586
# 1732        6.605840         36261         10.498498     49.041048
# 1853        6.448513         64717         11.077779    102.438893
# 2140        6.711956         48689         10.793208     59.219608
# 2205        6.910917         11661          9.364005     11.624186
# 2406        6.731120          4769          8.469892      5.690354
# 2679        6.144325         14065          9.551445     30.178194
# 3025        6.472091         25594         10.150113     39.568051
#
#       log_pop_den_2015  bar_big bar_small  hot_big hot_small
# 85           -2.216044      NaN       NaN      4.0         S
# 205           4.283963      8.0         S     24.0        16
# 421           4.428576      NaN         3      7.0         S
# 443           5.243080      NaN         S     24.0         8
# 524           4.315308      3.0         S     12.0         D
# 580           0.527711      5.0         S      5.0         4
# 1155          3.328887      NaN         S      5.0         4
# 1248          3.991570      7.0         S      3.0         9
# 1407          3.222461      NaN         D      NaN         S
# 1416          3.854999      NaN         S      2.0       NaN
# 1732          3.892658     10.0         S     11.0         D
# 1853          4.629266     15.0         S      7.0         9
# 2140          4.081253      4.0         S     23.0       NaN
# 2205          2.453088      NaN         S      1.0         4
# 2406          1.738772      3.0         S      2.0         4
# 2679          3.407120      NaN         S      5.0         D
# 3025          3.678022      7.0         S     10.0         D

# %%
len(result_any_S)
# Out:
# 17

# %%
result_no_noval = result4.loc[(result4['bar_small'] != 'S') & (result4['hot_small'] != 'S') 
                              & (result4['bar_small'] != 'D') & (result4['hot_small'] != 'D')]
print(len(result4), len(result_no_noval))
# Out:
# 3142 1527

# %%
result_no_hot_noval = result4.loc[(result4['hot_small'] != 'S') 
                              & (result4['hot_small'] != 'D')]
result_no_hot_noval['hot_small'] = result_no_hot_noval['hot_small'].astype(float)
min_hot_noval = result_no_hot_noval['hot_small'].min()
min_hot_noval
# Out:
# /anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 3.0

# %%
result_no_bar_noval = result4.loc[(result4['bar_small'] != 'S') 
                              & (result4['bar_small'] != 'D')]
result_no_bar_noval['bar_small'] = result_no_bar_noval['bar_small'].astype(float)
min_bar_noval = result_no_bar_noval['bar_small'].min()
min_bar_noval
# Out:
# /anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 3.0

# %%
# result_no_hot_noval_big = result4.loc[(result4['hot_big'] != 'S') & (result4['hot_big'] != 'D')]
result4['hot_big'] = result4['hot_big'].astype(float)
min_hot_noval_big = result4['hot_big'].min()


# result_no_bar_noval_big = result4.loc[(result4['bar_big'] != 'S') & (result4['bar_big'] != 'D')]
result4['bar_big'] = result4['bar_big'].astype(float)
min_bar_noval_big = result4['bar_big'].min()
print(min_hot_noval_big, min_bar_noval_big)

result4['bar_big'].fillna(min_bar_noval_big, inplace=True)
result4['hot_big'].fillna(min_hot_noval_big, inplace=True)
# Out:
# 1.0 1.0

# %%
result4['bar_small'].fillna(3, inplace=True)
result4['hot_small'].fillna(3, inplace=True)

# %%
result4.replace('D', 1.5, inplace=True)
result4.replace('S', 1.5, inplace=True)

# %%
result4['hotels'] = result4['hot_big'].astype(float) + result4['hot_small'].astype(float)
result4['bars'] = result4['bar_big'].astype(float) + result4['bar_small'].astype(float)

# %%
result4
# Out:
#      geo_id state_name state_code         county_name  area_sqmi  \
# 0      1001    Alabama         AL      Autauga County    594.439
# 1      1003    Alabama         AL      Baldwin County   1589.808
# 2      1005    Alabama         AL      Barbour County    884.877
# 3      1007    Alabama         AL         Bibb County    622.583
# 4      1009    Alabama         AL       Blount County    644.807
# 5      1011    Alabama         AL      Bullock County    622.806
# 6      1013    Alabama         AL       Butler County    776.828
# 7      1015    Alabama         AL      Calhoun County    605.889
# 8      1017    Alabama         AL     Chambers County    596.531
# 9      1019    Alabama         AL     Cherokee County    553.720
# 10     1021    Alabama         AL      Chilton County    692.854
# 11     1023    Alabama         AL      Choctaw County    913.500
# 12     1025    Alabama         AL       Clarke County   1238.466
# 13     1027    Alabama         AL         Clay County    603.961
# 14     1029    Alabama         AL     Cleburne County    560.105
# 15     1031    Alabama         AL       Coffee County    678.986
# 16     1033    Alabama         AL      Colbert County    592.620
# 17     1035    Alabama         AL      Conecuh County    850.157
# 18     1037    Alabama         AL        Coosa County    650.926
# 19     1039    Alabama         AL    Covington County   1030.457
# 20     1041    Alabama         AL     Crenshaw County    608.840
# 21     1043    Alabama         AL      Cullman County    734.898
# 22     1045    Alabama         AL         Dale County    561.150
# 23     1047    Alabama         AL       Dallas County    978.695
# 24     1049    Alabama         AL       DeKalb County    777.094
# 25     1051    Alabama         AL       Elmore County    618.488
# 26     1053    Alabama         AL     Escambia County    945.080
# 27     1055    Alabama         AL       Etowah County    535.284
# 28     1057    Alabama         AL      Fayette County    627.684
# 29     1059    Alabama         AL     Franklin County    633.817
# ...     ...        ...        ...                 ...        ...
# 3112  55129  Wisconsin         WI     Washburn County    797.113
# 3113  55131  Wisconsin         WI   Washington County    430.632
# 3114  55133  Wisconsin         WI     Waukesha County    549.605
# 3115  55135  Wisconsin         WI      Waupaca County    747.620
# 3116  55137  Wisconsin         WI     Waushara County    626.189
# 3117  55139  Wisconsin         WI    Winnebago County    434.487
# 3118  55141  Wisconsin         WI         Wood County    792.947
# 3119  56001    Wyoming         WY       Albany County   4274.331
# 3120  56003    Wyoming         WY     Big Horn County   3136.495
# 3121  56005    Wyoming         WY     Campbell County   4802.282
# 3122  56007    Wyoming         WY       Carbon County   7897.551
# 3123  56009    Wyoming         WY     Converse County   4254.872
# 3124  56011    Wyoming         WY        Crook County   2854.468
# 3125  56013    Wyoming         WY      Fremont County   9183.861
# 3126  56015    Wyoming         WY       Goshen County   2225.385
# 3127  56017    Wyoming         WY  Hot Springs County   2004.101
# 3128  56019    Wyoming         WY      Johnson County   4154.152
# 3129  56021    Wyoming         WY      Laramie County   2685.920
# 3130  56023    Wyoming         WY      Lincoln County   4076.224
# 3131  56025    Wyoming         WY      Natrona County   5340.515
# 3132  56027    Wyoming         WY     Niobrara County   2626.016
# 3133  56029    Wyoming         WY         Park County   6939.750
# 3134  56031    Wyoming         WY       Platte County   2084.191
# 3135  56033    Wyoming         WY     Sheridan County   2523.391
# 3136  56035    Wyoming         WY     Sublette County   4886.505
# 3137  56037    Wyoming         WY   Sweetwater County  10426.711
# 3138  56039    Wyoming         WY        Teton County   3995.988
# 3139  56041    Wyoming         WY        Uinta County   2081.831
# 3140  56043    Wyoming         WY     Washakie County   2238.552
# 3141  56045    Wyoming         WY       Weston County   2398.108
#
#       log_aland_sqmi  pop_est_2015  log_pop_est_2015  pop_den_2015  \
# 0           6.387618         55347         10.921378     93.107956
# 1           7.371369        203709         12.224448    128.134341
# 2           6.785449         26489         10.184485     29.935234
# 3           6.433877         22583         10.024953     36.273075
# 4           6.468951         57673         10.962544     89.442267
# 5           6.434235         10696          9.277625     17.173887
# 6           6.655219         20154          9.911158     25.943967
# 7           6.406697        115620         11.658064    190.827033
# 8           6.391131         34123         10.437727     57.202392
# 9           6.316659         25859         10.160414     46.700498
# 10          6.540819         43943         10.690649     63.423174
# 11          6.817283         13170          9.485697     14.417077
# 12          7.121629         24675         10.113546     19.923841
# 13          6.403510         13555          9.514511     22.443502
# 14          6.328124         15018          9.617005     26.812830
# 15          6.520601         51211         10.843710     75.422763
# 16          6.384553         54354         10.903273     91.718133
# 17          6.745421         12672          9.447150     14.905482
# 18          6.478396         10724          9.280239     16.474991
# 19          6.937758         37835         10.540990     36.716719
# 20          6.411556         13963          9.544166     22.933776
# 21          6.599732         82005         11.314535    111.586914
# 22          6.329988         49565         10.811040     88.327542
# 23          6.886220         41131         10.624517     42.026372
# 24          6.655561         71130         11.172264     91.533328
# 25          6.427278         81468         11.307966    131.721230
# 26          6.851270         37789         10.539773     39.984975
# 27          6.282797        103057         11.543038    192.527705
# 28          6.442037         16759          9.726691     26.699741
# 29          6.451760         31696         10.363946     50.008125
# ...              ...           ...               ...           ...
# 3112        6.680996         15552          9.651945     19.510408
# 3113        6.065254        133674         11.803159    310.413532
# 3114        6.309200        396488         12.890401    721.405373
# 3115        6.616895         51945         10.857941     69.480485
# 3116        6.439652         24033         10.087183     38.379786
# 3117        6.074166        169546         12.040880    390.221111
# 3118        6.675756         73435         11.204156     92.610225
# 3119        8.360383         37956         10.544183      8.879986
# 3120        8.050861         12022          9.394494      3.832941
# 3121        8.476847         49220         10.804055     10.249294
# 3122        8.974308         15559          9.652395      1.970104
# 3123        8.355820         14236          9.563529      3.345812
# 3124        7.956641          7444          8.915164      2.607841
# 3125        9.125203         40315         10.604479      4.389766
# 3126        7.707685         13383          9.501741      6.013791
# 3127        7.602951          4741          8.464003      2.365649
# 3128        8.331864          8585          9.057772      2.066607
# 3129        7.895779         97121         11.483713     36.159305
# 3130        8.312926         18722          9.837455      4.592976
# 3131        8.583077         82178         11.316643     15.387655
# 3132        7.873223          2542          7.840706      0.968006
# 3133        8.845021         29228         10.282882      4.211679
# 3134        7.642136          8812          9.083870      4.228019
# 3135        7.833359         30009         10.309253     11.892331
# 3136        8.494233          9899          9.200189      2.025783
# 3137        9.252126         44626         10.706072      4.279969
# 3138        8.293046         23125         10.048670      5.787054
# 3139        7.641003         20822          9.943765     10.001772
# 3140        7.713585          8328          9.027379      3.720262
# 3141        7.782435          7234          8.886547      3.016545
#
#       log_pop_den_2015  bar_big bar_small  hot_big hot_small  hotels   bars
# 0             4.533760      1.0       1.5      8.0       1.5     9.5    2.5
# 1             4.853079     12.0        24     51.0        34    85.0   36.0
# 2             3.399036      1.0       1.5      9.0         3    12.0    2.5
# 3             3.591076      1.0       1.5      1.0       1.5     2.5    2.5
# 4             4.493593      1.0       1.5      2.0         3     5.0    2.5
# 5             2.843390      1.0         3      1.0       1.5     2.5    4.0
# 6             3.255939      1.0         3      7.0         3    10.0    4.0
# 7             5.251367      4.0         6     27.0         8    35.0   10.0
# 8             4.046596      1.0         5      3.0       1.5     4.5    6.0
# 9             3.843755      1.0         3      3.0         4     7.0    4.0
# 10            4.149829      1.0         6      6.0         3     9.0    7.0
# 11            2.668413      1.0       1.5      3.0         3     6.0    2.5
# 12            2.991917      1.0       1.5      7.0         4    11.0    2.5
# 13            3.111001      1.0       1.5      1.0       1.5     2.5    2.5
# 14            3.288880      1.0       1.5      1.0       1.5     2.5    2.5
# 15            4.323109      2.0       1.5     11.0         4    15.0    3.5
# 16            4.518720      3.0         3     10.0       1.5    11.5    6.0
# 17            2.701729      1.0         3      3.0         3     6.0    4.0
# 18            2.801844      1.0         3      1.0         3     4.0    4.0
# 19            3.603232      1.0         6      8.0         5    13.0    7.0
# 20            3.132611      1.0       1.5      1.0       1.5     2.5    2.5
# 21            4.714804      1.0         3     13.0         7    20.0    4.0
# 22            4.481052      3.0         7      7.0         3    10.0   10.0
# 23            3.738297      2.0         6      8.0         8    16.0    8.0
# 24            4.516703      1.0         3      7.0         7    14.0    4.0
# 25            4.880688      3.0         3      8.0       1.5     9.5    6.0
# 26            3.688504      1.0         3      7.0         4    11.0    4.0
# 27            5.260240      7.0         4     16.0       1.5    17.5   11.0
# 28            3.284654      1.0         3      1.0       1.5     2.5    4.0
# 29            3.912185      1.0       1.5      2.0         6     8.0    2.5
# ...                ...      ...       ...      ...       ...     ...    ...
# 3112          2.970948     21.0        13     11.0         9    20.0   34.0
# 3113          5.737905     50.0        29     14.0         8    22.0   79.0
# 3114          6.581201     94.0        38     38.0        31    69.0  132.0
# 3115          4.241046     35.0        29     12.0        13    25.0   64.0
# 3116          3.647531     15.0        12      4.0         6    10.0   27.0
# 3117          5.966714     93.0        34     24.0        19    43.0  127.0
# 3118          4.528400     50.0        19     11.0         6    17.0   69.0
# 3119          2.183800     11.0         3     23.0        12    35.0   14.0
# 3120          1.343632      7.0         3      7.0         5    12.0   10.0
# 3121          2.327209     12.0       1.5     23.0         4    27.0   13.5
# 3122          0.678087     13.0       1.5     30.0        11    41.0   14.5
# 3123          1.207709      3.0         3     10.0       1.5    11.5    6.0
# 3124          0.958523      4.0       1.5      5.0         9    14.0    5.5
# 3125          1.479276     17.0         3     26.0        12    38.0   20.0
# 3126          1.794055      5.0       1.5      3.0       1.5     4.5    6.5
# 3127          0.861053      1.0         3      5.0         3     8.0    4.0
# 3128          0.725908      2.0         3     14.0         6    20.0    5.0
# 3129          3.587934     19.0         3     37.0         8    45.0   22.0
# 3130          1.524528      5.0       1.5     17.0         9    26.0    6.5
# 3131          2.733566     11.0         4     23.0        12    35.0   15.0
# 3132         -0.032517      1.0         3      3.0       1.5     4.5    4.0
# 3133          1.437861      3.0         4     39.0        14    53.0    7.0
# 3134          1.441734      2.0       1.5      8.0       1.5     9.5    3.5
# 3135          2.475894     12.0       1.5     25.0         7    32.0   13.5
# 3136          0.705956      6.0         3     12.0         5    17.0    9.0
# 3137          1.453946     20.0       1.5     23.0         3    26.0   21.5
# 3138          1.755623      8.0       1.5     59.0        12    71.0    9.5
# 3139          2.302762      3.0       1.5     12.0       1.5    13.5    4.5
# 3140          1.313794      4.0         3      8.0       1.5     9.5    7.0
# 3141          1.104112      2.0         4      6.0       1.5     7.5    6.0
#
# [3142 rows x 16 columns]

# %%
result4.to_csv('../data/2015_master_sd_1_5_nan_to_min.csv')

# %%
result4_toy = result4[['geo_id', 'state_name', 'state_code', 'county_name', 'area_sqmi', 'pop_est_2015', 'hotels', 'bars']]
result4_toy.to_csv('../data/2015_toy_sd_1_5_nan_to_min.csv')

# %%
result4_toy['hotels'].hist();

# %%
result4_toy['bars'].hist();

# %%
result4_toy['log_bars'] = np.log10(result4_toy['bars'])
result4_toy['log_hotels'] = np.log10(result4_toy['hotels'])
# Out:
# /anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result4_toy['log_hotels'].hist();

# %%
result4_toy['log_bars'].hist();

# %%
x = result4['log_aland_sqmi']
y = result4['log_pop_est_2015']
z = result4_toy['log_hotels']

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(15, 5))

ax0.scatter(x, y, alpha=0.3);
ax0.set_title('Area - Population')
ax0.set_xlabel('Log of the area (in log(square miles)')
ax0.set_ylabel('Log of number of residents')

ax1.scatter(x, z, alpha=0.3);
ax1.set_title('Area - log_hotels')
ax1.set_xlabel('Log of the area (in log(square miles)')
ax1.set_ylabel('log_hotels')

ax2.scatter(y, z, alpha=0.3);
ax2.set_title('Population - log_hotels')
ax2.set_xlabel('Log of number of residents')
ax2.set_ylabel('log_hotels')

plt.savefig('../figures/area_pop_hotels_scatters.png')
fig.tight_layout()

# %%
x = result4['log_aland_sqmi']
y = result4['log_pop_est_2015']
z = result4_toy['log_bars']

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(15, 5))

ax0.scatter(x, y, alpha=0.3);
ax0.set_title('Area - Population')
ax0.set_xlabel('Log of the area (in log(square miles)')
ax0.set_ylabel('Log of number of residents')

ax1.scatter(x, z, alpha=0.3);
ax1.set_title('Area - log_bars')
ax1.set_xlabel('Log of the area (in log(square miles)')
ax1.set_ylabel('log_bars')

ax2.scatter(y, z, alpha=0.3);
ax2.set_title('Population - log_bars')
ax2.set_xlabel('Log of number of residents')
ax2.set_ylabel('log_bars')

plt.savefig('../figures/area_pop_bars_scatters.png')
fig.tight_layout()
